# %%
# !ls
# Out:
# compute_flow.py  __pycache__  Untitled.ipynb

# %%
from compute_flow import calculate_flow

# %%
impath_1 = '../../MFF-pytorch/datasets/jester-small/4/00002.jpg' 
impath_2 = '../../MFF-pytorch/datasets/jester-small/4/00003.jpg'

# %%
flow = calculate_flow(impath_1, impath_2)

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(flow[:,:,0], cmap='gray')
